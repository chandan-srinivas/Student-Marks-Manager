# %%
class Progress:
  def __init__(self,name,marks,cl):
    self.name=name
    self.marks=marks
    self.cl=cl

  def form(self):
    print("=============================================================================================")
    print(f"                              Report Of Class {self.cl}                                     ")
    print("=============================================================================================")
    print()
    if len(self.marks)==5:
      print("Student_name",end="    ")
      print("Telugu  Hindi  English  Maths  EVS  Total  Full_Marks  P/F")
    elif len(self.marks)==6:
      print("Student_name",end="    ")
      print("Telugu  Hindi  English  Maths  Science  Social  Total  Full_Marks  P/F")
    else:
      print("Student_name",end="    ")
      print("Telugu  Hindi  English  Maths  Physics  Biology  Social  Total  Full_Marks  P/F")

  def display(self):
    print(self.name,end="          ")
    for i in self.marks:
      print(i,end="      ")
    print(sum(self.marks),end="     ")
    print(len(self.marks)*100,end="      ")
    for i in self.marks:
      if i<35:
        print("F",end="    ")
        break
    else:
      print("P",end="    ")
    print()

  def markslen(self):
    return len(self.marks)

  def Topper(self):
    self.me=" "
    self.m=0
    if sum(self.marks)>self.m:
      self.m=sum(self.marks)
      self.me=self.name
    return [self.me,self.m]

  def PassCount(self):
    flag=0
    for i in self.marks:
      if i>=35:
        flag+=1
    return flag

  def FailCount(self):
    flag=0
    for i in self.marks:
      if i>=35:
        flag+=1
    return flag

st1=[]
st2=[]
st3=[]
st4=[]
st5=[]
st6=[]
st7=[]
st8=[]
st9=[]
st10=[]
while True:
  cl=int(input("Enter Class: "))
  match cl:
    case 1:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,EVS Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st1.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st1:
              i.display()
          case 2:
            l=[]
            for i in st1:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st1:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st1:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st1:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st1:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")

    case 2:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,EVS Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st2.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st2:
              i.display()
          case 2:
            l=[]
            for i in st2:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st2:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st2:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st2:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st2:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 3:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,EVS Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st3.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st3:
              i.display()
          case 2:
            l=[]
            for i in st3:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st3:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st3:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st3:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st3:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 4:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Science,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st4.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st4:
              i.display()
          case 2:
            l=[]
            for i in st4:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st4:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st4:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st4:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st4:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")

    case 5:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Science,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st5.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st5:
              i.display()
          case 2:
            l=[]
            for i in st5:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st5:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st5:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st5:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st5:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 6:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Science,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st6.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st6:
              i.display()
          case 2:
            l=[]
            for i in st6:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st6:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st6:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st6:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st6:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 7:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Science,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st7.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st7:
              i.display()
          case 2:
            l=[]
            for i in st7:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st7:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st7:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st7:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st7:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 8:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Physics,Biology,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st8.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st8:
              i.display()
          case 2:
            l=[]
            for i in st8:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st8:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st8:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st8:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st8:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 9:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Physics,Biology,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st9.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st9:
              i.display()
          case 2:
            l=[]
            for i in st9:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st9:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st9:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st9:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st9:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case 10:
      print("===================================================================================================")
      print("                          If You Want to add Students:                                            ")
      ch=input("                        Enter The option --> Y/N: ")
      print("===================================================================================================")
      if ch.lower()=="y":
        print()
        n=int(input("         Enter the no.of Students: "))
        for i in range(n):
          name=input( f"      Enter Name of the student {i+1}: ")
          print(f"            Enter Telugu,Hindi,English,Maths,Physics,Biology,Social Marks for student {i+1}: ",end="  ")
          marks=[int(i) for i in input().split()]
          c1=Progress(name,marks,cl)
          st10.append(c1)
      else:
        print()
        print("--------------------------------------------------------------------------------------------------")
        print("1. Progress Report  2.Topper 3. Pass Count  4. Fail Count  5. Pass Percentage  6. Fail Percentage")
        print("--------------------------------------------------------------------------------------------------")
        ch=int(input("                    Enter Your Choice: "))
        if ch==1:
          c1.form()
        match ch:
          case 1:
            for i in st10:
              i.display()
          case 2:
            l=[]
            for i in st10:
              l.append(i.Topper())
            nm=l[0][0]
            m=l[0][1]
            for i in l:
              if i[1]>m:
                nm=i[0]
                m=i[1]
            print(f"           Topper Name: {nm} with {m} marks")
          case 3:
            c=0
            for i in st10:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Studetns Passed: {c}")
          case 4:
            c=0
            for i in st10:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Students Failed: {c}")
          case 5:
            c=0
            for i in st10:
              if i.PassCount()==i.markslen():
                c+=1
            print(f"           Total No.of Students Passed: {c}")
            print(f"           Pass Percentage: {(c/len(st1))*100}")
          case 6:
            c=0
            for i in st10:
              if i.FailCount()==i.markslen():
                pass
              else:
                c+=1
            print(f"           Total No.of Studetns Failed: {c}")
            print(f"           Fail Percentage: {(c/len(st1))*100}")
          case _:
            print("Invalid Choice")
    case _:
      print("Invalid Class Number")

  print("Do you Want to add or see Other classes Report ")
  o=input("Enter The option --> Y/N: ")
  if o.lower()=="n":
    break
# Out:
# Enter Class: 10
# ...
#                           If You Want to add Students:
#                         Enter The option --> Y/N: y
# ...
#
#          Enter the no.of Students: 2
#       Enter Name of the student 1: Chandan
#             Enter Telugu,Hindi,English,Maths,Physics,Biology,Social Marks for student 1:   98 97 96 99 100
#       Enter Name of the student 2: Tejesh
#             Enter Telugu,Hindi,English,Maths,Physics,Biology,Social Marks for student 2:   96 97 98 35 31
# Do you Want to add or see Other classes Report
# Enter The option --> Y/N: y
# Enter Class: 1
# ...
#                           If You Want to add Students:
#                         Enter The option --> Y/N: y
# ...
#
#          Enter the no.of Students: 3
#       Enter Name of the student 1: Vinay
#             Enter Telugu,Hindi,English,Maths,EVS Marks for student 1:   55 96 78 84 95
#       Enter Name of the student 2: Raghu
#             Enter Telugu,Hindi,English,Maths,EVS Marks for student 2:   96 32 4 55 62
# ...
